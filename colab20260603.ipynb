# %% [markdown]
# <a href="https://colab.research.google.com/github/zencolab/WhatDreamsCost-ComfyUI/blob/main/colab20260603.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# Cell 1: 基础环境与插件管理器 (内置通用安装函数)
# ==========================================
import os, subprocess
print("=== 🚀 开始安装 ComfyUI 基础与图像模块 ===")
# %cd /content

if not os.path.exists("ComfyUI"):
    # !git clone https://github.com/comfyanonymous/ComfyUI
else:
    # !cd ComfyUI && git pull

# %cd /content/ComfyUI
# !pip install -q -r requirements.txt huggingface_hub hf_transfer

# 定义通用节点安装函数以复用代码
def install_node(repo_url):
    folder_name = repo_url.split('/')[-1].replace('.git', '')
    target_path = f"/content/ComfyUI/custom_nodes/{folder_name}"
    if not os.path.exists(target_path):
        # !git clone {repo_url} {target_path}
        if os.path.exists(f"{target_path}/requirements.txt"):
            # !pip install -q -r {target_path}/requirements.txt
    else:
        # !cd {target_path} && git pull

# 安装基础核心插件
base_nodes = [
    "https://github.com/ltdrdata/ComfyUI-Manager.git",
    "https://github.com/rgthree/rgthree-comfy.git"
]
for node in base_nodes:
    install_node(node)
print("\n✅ Cell 1 安装完成！")
# Out:
# === 🚀 开始安装 ComfyUI 基础与图像模块 ===
# /content
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 40295, done.
# remote: Counting objects: 100% (308/308), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 40295 (delta 252), reused 192 (delta 192), pack-reused 39987 (from 2)
# Receiving objects: 100% (40295/40295), 88.44 MiB | 38.21 MiB/s, done.
# Resolving deltas: 100% (27145/27145), done.
# /content/ComfyUI
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.7/22.7 MB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 134.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.2/340.2 kB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 MB 34.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 MB 38.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 MB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 MB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 185.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 102.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.8/320.8 kB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 172.1 MB/s eta 0:00:00
# Cloning into '/content/ComfyUI/custom_nodes/ComfyUI-Manager'...
# remote: Enumerating objects: 30644, done.
# remote: Counting objects: 100% (841/841), done.
# remote: Compressing objects: 100% (328/328), done.
# remote: Total 30644 (delta 699), reused 515 (delta 513), pack-reused 29803 (from 4)
# Receiving objects: 100% (30644/30644), 161.41 MiB | 39.65 MiB/s, done.
# Resolving deltas: 100% (22689/22689), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.7/449.7 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 167.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 155.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 127.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 6.6 MB/s eta 0:00:00
# Cloning into '/content/ComfyUI/custom_nodes/rgthree-comfy'...
# remote: Enumerating objects: 4723, done.
# remote: Counting objects: 100% (1552/1552), done.
# remote: Compressing objects: 100% (393/393), done.
# remote: Total 4723 (delta 1314), reused 1160 (delta 1159), pack-reused 3171 (from 3)
# Receiving objects: 100% (4723/4723), 5.04 MiB | 2.09 MiB/s, done.
# Resolving deltas: 100% (3456/3456), done.
#
# ✅ Cell 1 安装完成！

# %% [markdown]
# ALL-ONE-IN最全脚本

# %%
# ==========================================
# 终极节点自动化安装脚本（修复 ComfyMath + LTXVideo依赖 + LayerStyle + EasyUse + Masquerade）
# ==========================================
import os
import subprocess

# 请确认这是你的 ComfyUI 根目录路径（Colab / 云实例通常是这个）
comfyui_dir = "/content/ComfyUI"
custom_nodes_dir = os.path.join(comfyui_dir, "custom_nodes")

# 修正后的节点清单
node_repos = [
    "https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git",
    "https://github.com/kijai/ComfyUI-KJNodes.git",
    "https://github.com/Lightricks/ComfyUI-LTXVideo.git",
    "https://github.com/Fannovel16/comfyui_controlnet_aux.git",
    "https://github.com/cubiq/ComfyUI_essentials.git",
    "https://github.com/yuvraj108c/ComfyUI-Video-Depth-Anything.git",
    #"https://github.com/ai-shizuka/comfyui-tbox.git",
    "https://github.com/evanspearman/ComfyMath.git",
    #"https://github.com/Smirnov75/ComfyUI-mxToolkit.git",
    "https://github.com/chrisgoringe/cg-use-everywhere.git",

    "https://github.com/rgthree/rgthree-comfy.git",

    "https://github.com/ltdrdata/ComfyUI-Impact-Pack.git",
    "https://github.com/pythongosssss/ComfyUI-Custom-Scripts.git",
    #"https://github.com/city96/ComfyUI-GGUF.git",
    "https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes.git",
    "https://github.com/WASasquatch/was-node-suite-comfyui.git",
    "https://github.com/cubiq/ComfyUI_IPAdapter_plus.git",
    "https://github.com/DoctorDiffusion/ComfyUI-MediaMixer.git",
    "https://github.com/ltdrdata/ComfyUI-Inspire-Pack.git",
    "https://github.com/11cafe/comfyui-workspace-manager.git",
    "https://github.com/kijai/ComfyUI-PromptRelay.git",

    "https://github.com/Saganaki22/ComfyUI-FishAudioS2.git",
    "https://github.com/WhatDreamsCost/WhatDreamsCost-ComfyUI.git",

    # 修复上一轮缺失的节点
    "https://github.com/chflame163/ComfyUI_LayerStyle.git",
    "https://github.com/yolain/ComfyUI-Easy-Use.git",

    # ==========================================
    # ▼ 本次新增：修复 Image To Mask 节点 ▼
    # ==========================================
    "https://github.com/BadCafeCode/masquerade-nodes-comfyui.git"
]

print("=== 🚀 开始自动化下载并安装节点及其依赖 ===")

os.makedirs(custom_nodes_dir, exist_ok=True)

for repo in node_repos:
    repo_name = repo.split('/')[-1].replace('.git', '')
    repo_path = os.path.join(custom_nodes_dir, repo_name)

    if not os.path.exists(repo_path):
        print(f"\n📥 正在克隆: {repo_name}...")
        result = subprocess.run(["git", "clone", repo, repo_path], capture_output=True, text=True)
        if result.returncode != 0:
            print(f"   ❌ 克隆失败: {result.stderr}")
        else:
            print(f"   ✅ 克隆成功")
    else:
        print(f"\n✅ 已存在: {repo_name}，正在尝试拉取更新...")
        pull_result = subprocess.run(["git", "pull"], cwd=repo_path, capture_output=True, text=True)
        if pull_result.returncode != 0:
            print(f"   ⚠️ 更新失败 (可能是本地有冲突，请手动检查): {pull_result.stderr.strip()}")
        else:
            print(f"   🔄 代码已是最新或更新成功")

    # 安装依赖
    req_file = os.path.join(repo_path, "requirements.txt")
    if os.path.exists(req_file):
        print(f"   ⚙️ 安装 {repo_name} 的依赖...")
        subprocess.run(["pip", "install", "-r", req_file, "--quiet"])
    else:
        print(f"   ⏭️ {repo_name} 无 requirements.txt")

# ==========================================
# 🔧 针对 LTXVideo 的 Kornia 冲突修复补丁
# ==========================================
print("\n=== 🔧 执行特定节点依赖修复 (ComfyUI-LTXVideo) ===")
print("   ⬇️ 强制降级 kornia==0.7.2...")
subprocess.run(["pip", "install", "kornia==0.7.2", "--quiet"])

ltx_req = os.path.join(custom_nodes_dir, "ComfyUI-LTXVideo", "requirements.txt")
if os.path.exists(ltx_req):
    print("   ⚙️ 重新校验 LTXVideo 依赖树...")
    subprocess.run(["pip", "install", "-r", ltx_req, "--quiet"])
else:
    print("   ⏭️ 未找到 LTXVideo requirements.txt，跳过校验")

# ==========================================
# 全局常用依赖
# ==========================================
print("\n=== 📦 安装全局常用库 ===")
subprocess.run(["pip", "install", "--quiet", "opencv-python-headless", "scikit-image", "onnxruntime-gpu", "sageattention", "gguf"])

print("\n🎉 所有节点安装及更新完成！请重启 ComfyUI（Restart）")
# Out:
# === 🚀 开始自动化下载并安装节点及其依赖 ===
#
# 📥 正在克隆: ComfyUI-VideoHelperSuite...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-VideoHelperSuite 的依赖...
#
# 📥 正在克隆: ComfyUI-KJNodes...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-KJNodes 的依赖...
#
# 📥 正在克隆: ComfyUI-LTXVideo...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-LTXVideo 的依赖...
#
# 📥 正在克隆: comfyui_controlnet_aux...
#    ✅ 克隆成功
#    ⚙️ 安装 comfyui_controlnet_aux 的依赖...
#
# 📥 正在克隆: ComfyUI_essentials...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI_essentials 的依赖...
#
# 📥 正在克隆: ComfyUI-Video-Depth-Anything...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-Video-Depth-Anything 的依赖...
#
# 📥 正在克隆: ComfyMath...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyMath 的依赖...
#
# 📥 正在克隆: cg-use-everywhere...
#    ✅ 克隆成功
#    ⏭️ cg-use-everywhere 无 requirements.txt
#
# ✅ 已存在: rgthree-comfy，正在尝试拉取更新...
#    🔄 代码已是最新或更新成功
#    ⚙️ 安装 rgthree-comfy 的依赖...
#
# 📥 正在克隆: ComfyUI-Impact-Pack...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-Impact-Pack 的依赖...
#
# 📥 正在克隆: ComfyUI-Custom-Scripts...
#    ✅ 克隆成功
#    ⏭️ ComfyUI-Custom-Scripts 无 requirements.txt
#
# 📥 正在克隆: was-node-suite-comfyui...
#    ✅ 克隆成功
#    ⚙️ 安装 was-node-suite-comfyui 的依赖...
#
# 📥 正在克隆: ComfyUI_IPAdapter_plus...
#    ✅ 克隆成功
#    ⏭️ ComfyUI_IPAdapter_plus 无 requirements.txt
#
# 📥 正在克隆: ComfyUI-MediaMixer...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-MediaMixer 的依赖...
#
# 📥 正在克隆: ComfyUI-Inspire-Pack...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-Inspire-Pack 的依赖...
#
# 📥 正在克隆: comfyui-workspace-manager...
#    ✅ 克隆成功
#    ⚙️ 安装 comfyui-workspace-manager 的依赖...
#
# 📥 正在克隆: ComfyUI-PromptRelay...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-PromptRelay 的依赖...
#
# 📥 正在克隆: ComfyUI-FishAudioS2...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-FishAudioS2 的依赖...
#
# 📥 正在克隆: WhatDreamsCost-ComfyUI...
#    ✅ 克隆成功
#    ⏭️ WhatDreamsCost-ComfyUI 无 requirements.txt
#
# 📥 正在克隆: ComfyUI_LayerStyle...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI_LayerStyle 的依赖...
#
# 📥 正在克隆: ComfyUI-Easy-Use...
#    ✅ 克隆成功
#    ⚙️ 安装 ComfyUI-Easy-Use 的依赖...
#
# 📥 正在克隆: masquerade-nodes-comfyui...
#    ✅ 克隆成功
#    ⏭️ masquerade-nodes-comfyui 无 requirements.txt
#
# === 🔧 执行特定节点依赖修复 (ComfyUI-LTXVideo) ===
#    ⬇️ 强制降级 kornia==0.7.2...
#    ⚙️ 重新校验 LTXVideo 依赖树...
#
# === 📦 安装全局常用库 ===
#
# 🎉 所有节点安装及更新完成！请重启 ComfyUI（Restart）

# %%
# ==========================================
# 单独下载 Fish Audio S2 (s2-pro-fp8) 模型
# ==========================================
import os
from huggingface_hub import snapshot_download

# 设定 ComfyUI 的根目录（如果是本地环境，请修改为你的实际路径）
comfyui_dir = "/content/ComfyUI"

# 根据 Fish Audio S2 节点的要求，设定标准存放路径
target_dir = os.path.join(comfyui_dir, "models", "FishAudioS2", "s2-pro-fp8")

print(f"🚀 开始下载 s2-pro-fp8 模型...")
print(f"📂 目标安装路径: {target_dir}")

try:
    # 开启 HF 传输加速（可选）
    os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

    # 下载整个模型仓库到指定文件夹
    snapshot_download(
        repo_id="drbaph/s2-pro-fp8",
        local_dir=target_dir,
        local_dir_use_symlinks=False  # 禁用软链接，确保文件实实在在地存在于该目录
    )
    print("\n🎉 s2-pro-fp8 模型下载并安装成功！")
    print("👉 请重启 ComfyUI，并在 FishS2MultiSpeakerTTS 节点的 model_path 菜单中选择 's2-pro-fp8'。")

except Exception as e:
    print(f"\n❌ 下载失败，错误信息: {e}")
# Out:
# 🚀 开始下载 s2-pro-fp8 模型...
# 📂 目标安装路径: /content/ComfyUI/models/FishAudioS2/s2-pro-fp8
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# 🎉 s2-pro-fp8 模型下载并安装成功！
# 👉 请重启 ComfyUI，并在 FishS2MultiSpeakerTTS 节点的 model_path 菜单中选择 's2-pro-fp8'。

# %%
# ==========================================
# Cell 3: 终极模型多线程极速同步 (25合1 防冲突&防重下 完美版)
# ==========================================
import os
import shutil
from google.colab import userdata
from huggingface_hub import hf_hub_download
from concurrent.futures import ThreadPoolExecutor

os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
try:
    os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')
except:
    raise Exception("❌ 请在左侧 '🔑 Secrets' 中添加 'HF_TOKEN'")

downloads = [
    # --- 1. 基础核心模型 ---
    {"repo_id": "Lightricks/LTX-2.3-fp8", "filename": "ltx-2.3-22b-dev-fp8.safetensors", "final_dir": "/content/ComfyUI/models/checkpoints"},
    {"repo_id": "Lightricks/LTX-2.3", "filename": "ltx-2.3-22b-distilled-lora-384-1.1.safetensors", "final_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2.3", "filename": "ltx-2.3-spatial-upscaler-x2-1.1.safetensors", "final_dir": "/content/ComfyUI/models/latent_upscale_models"},
    {"repo_id": "Comfy-Org/ltx-2", "filename": "split_files/text_encoders/gemma_3_12B_it_fp4_mixed.safetensors", "final_dir": "/content/ComfyUI/models/text_encoders"},
    {"repo_id": "Comfy-Org/ltx-2.3", "filename": "split_files/loras/ltx-2.3-id-lora-talkvid-3k.safetensors", "final_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2.3-22b-IC-LoRA-Union-Control", "filename": "ltx-2.3-22b-ic-lora-union-control-ref0.5.safetensors", "final_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2.3", "filename": "ltx-2.3-22b-distilled-1.1.safetensors", "final_dir": "/content/ComfyUI/models/checkpoints"},

    # --- 2. 社区增强与特征映射模型 ---
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "text_encoders/ltx-2.3_text_projection_bf16.safetensors", "final_dir": "/content/ComfyUI/models/text_encoders"},
    {"repo_id": "stronman/LTX-2.3-Transition-LORA", "filename": "ltx2.3-transition.safetensors", "final_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "stronman/Ltx2.3-VBVR-lora-I2V", "filename": "Ltx2.3-Licon-VBVR-I2V-390K-R32.safetensors", "final_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "loras/ltx-2.3-22b-distilled-lora-dynamic_fro09_avg_rank_105_bf16.safetensors", "final_dir": "/content/ComfyUI/models/loras", "flatten": True},

    # --- 3. LTX 官方功能性特效 LoRA ---
    {"repo_id": "Lightricks/LTX-2.3-22b-IC-LoRA-HDR", "filename": "ltx-2.3-22b-ic-lora-hdr-0.9.safetensors", "final_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2.3-22b-IC-LoRA-Motion-Track-Control", "filename": "ltx-2.3-22b-ic-lora-motion-track-control-ref0.5.safetensors", "final_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2.3-22b-IC-LoRA-LipDub", "filename": "ltx-2.3-22b-ic-lora-lipdub-0.9.safetensors", "final_dir": "/content/ComfyUI/models/loras"},

    # --- 4. IP-Adapter 与 图像特征模型 ---
    {"repo_id": "h94/IP-Adapter-FaceID", "filename": "ip-adapter-faceid-plusv2_sdxl.bin", "final_dir": "/content/ComfyUI/models/ipadapter"},
    {"repo_id": "h94/IP-Adapter", "filename": "models/image_encoder/model.safetensors", "final_dir": "/content/ComfyUI/models/clip_vision", "flatten": True, "rename_to": "CLIP-ViT-H-14-laion2B-s32B-b79K.safetensors"},

    # --- 5. 路径纠偏与重命名修复模型 ---
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "diffusion_models/ltx-2.3-22b-distilled-1.1_transformer_only_fp8_scaled.safetensors", "final_dir": "/content/ComfyUI/models/unet", "flatten": True},
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "vae/LTX23_video_vae_bf16.safetensors", "final_dir": "/content/ComfyUI/models/vae", "flatten": True},
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "vae/LTX23_audio_vae_bf16.safetensors", "final_dir": "/content/ComfyUI/models/vae", "flatten": True},

    # ⬇️ ICEdit-Insight 视频特效全家桶 (自动追加 -lora 后缀) ⬇️
    {"repo_id": "joyfox/LTX2.3-ICEdit-Insight", "filename": "ltx2.3-ic-watermark-remove-general.safetensors", "final_dir": "/content/ComfyUI/models/loras", "rename_to": "ltx2.3-ic-watermark-remove-general-lora.safetensors"},
    {"repo_id": "joyfox/LTX2.3-ICEdit-Insight", "filename": "ltx2.3-ic-subtitles-remove-general.safetensors", "final_dir": "/content/ComfyUI/models/loras", "rename_to": "ltx2.3-ic-subtitles-remove-general-lora.safetensors"},
    # [新增] 视频修复模型
    {"repo_id": "joyfox/LTX2.3-ICEdit-Insight", "filename": "ltx2.3-video-restoration-general.safetensors", "final_dir": "/content/ComfyUI/models/loras", "rename_to": "ltx2.3-video-restoration-general-lora.safetensors"},
    # [新增] 视频高清放大增强模型
    {"repo_id": "joyfox/LTX2.3-ICEdit-Insight", "filename": "ltx2.3-ic-video-upscale-general.safetensors", "final_dir": "/content/ComfyUI/models/loras", "rename_to": "ltx2.3-ic-video-upscale-general-lora.safetensors"},

    # --- 6. 额外补充模型 ---
    {"repo_id": "Muapi/ltx2.3-resolution-enhancement-guofeng", "filename": "ltx2.3-resolution-enhancement-guofeng.safetensors", "final_dir": "/content/ComfyUI/models/loras", "rename_to": "LTX-2.3-Guofeng-V0.1.safetensors"},
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "vae/taeltx2_3.safetensors", "final_dir": "/content/ComfyUI/models/vae", "flatten": True}
]

def download_model(task):
    try:
        # 建立最终目标文件夹
        os.makedirs(task["final_dir"], exist_ok=True)

        # 1. 提前计算该模型最终期望的绝对路径位置
        base_name = task.get("rename_to", os.path.basename(task["filename"]))
        final_path = os.path.join(task["final_dir"], base_name)

        # 💡 【核心防重下逻辑】：如果最终位置已经有这个文件了，直接跳过下载！
        if os.path.exists(final_path):
            print(f"⏩ 已存在，跳过下载: {base_name}")
            return

        # 2. 如果不存在，再向 HuggingFace 请求下载
        downloaded_path = hf_hub_download(
            repo_id=task["repo_id"],
            filename=task["filename"],
            local_dir=task["final_dir"],
            repo_type="model"
        )

        # 3. 纠偏剪切：处理多层级空文件夹和重命名
        if ("flatten" in task or "rename_to" in task) and downloaded_path != final_path:
            os.makedirs(os.path.dirname(final_path), exist_ok=True)
            if os.path.exists(final_path):
                os.remove(final_path)
            shutil.move(downloaded_path, final_path)

        print(f"✅ 成功就绪: {base_name}")
    except Exception as e:
        print(f"❌ 失败 {task['filename'].split('/')[-1]}: {e}")

print(f"🚀 开始启动多线程并发下载与智能分类，共 {len(downloads)} 个模型...")

# 使用 8 线程并发下载
with ThreadPoolExecutor(max_workers=8) as executor:
    executor.map(download_model, downloads)

print("\n🎉 全量模型并发同步 & 路径纠偏全部完成！")
# Out:
# 🚀 开始启动多线程并发下载与智能分类，共 25 个模型...
# ltx-2.3-22b-distilled-1.1.safetensors:   0%|          | 0.00/46.1G [00:00<?, ?B/s]
# split_files/loras/ltx-2.3-id-lora-talkvi(…):   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# ltx-2.3-spatial-upscaler-x2-1.1.safetens(…):   0%|          | 0.00/996M [00:00<?, ?B/s]
# ltx-2.3-22b-ic-lora-union-control-ref0.5(…):   0%|          | 0.00/654M [00:00<?, ?B/s]
# ltx-2.3-22b-distilled-lora-384-1.1.safet(…):   0%|          | 0.00/7.61G [00:00<?, ?B/s]
# ltx-2.3-22b-dev-fp8.safetensors:   0%|          | 0.00/29.1G [00:00<?, ?B/s]
# text_encoders/ltx-2.3_text_projection_bf(…):   0%|          | 0.00/2.31G [00:00<?, ?B/s]
# split_files/text_encoders/gemma_3_12B_it(…):   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# ✅ 成功就绪: ltx-2.3-22b-ic-lora-union-control-ref0.5.safetensors
# ✅ 成功就绪: ltx-2.3-spatial-upscaler-x2-1.1.safetensors
# ltx2.3-transition.safetensors:   0%|          | 0.00/390M [00:00<?, ?B/s]
# Ltx2.3-Licon-VBVR-I2V-390K-R32.safetenso(…):   0%|          | 0.00/554M [00:00<?, ?B/s]
# ✅ 成功就绪: ltx-2.3-id-lora-talkvid-3k.safetensors
# loras/ltx-2.3-22b-distilled-lora-dynamic(…):   0%|          | 0.00/2.59G [00:00<?, ?B/s]
# ✅ 成功就绪: Ltx2.3-Licon-VBVR-I2V-390K-R32.safetensors
# ltx-2.3-22b-ic-lora-hdr-0.9.safetensors:   0%|          | 0.00/327M [00:00<?, ?B/s]
# ✅ 成功就绪: ltx-2.3_text_projection_bf16.safetensors
# ltx-2.3-22b-ic-lora-motion-track-control(…):   0%|          | 0.00/327M [00:00<?, ?B/s]
# ✅ 成功就绪: ltx-2.3-22b-ic-lora-motion-track-control-ref0.5.safetensors
# ltx-2.3-22b-ic-lora-lipdub-0.9.safetenso(…):   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# ✅ 成功就绪: ltx-2.3-22b-ic-lora-hdr-0.9.safetensors
# ip-adapter-faceid-plusv2_sdxl.bin:   0%|          | 0.00/1.49G [00:00<?, ?B/s]
# ✅ 成功就绪: ltx-2.3-22b-distilled-lora-dynamic_fro09_avg_rank_105_bf16.safetensors
# models/image_encoder/model.safetensors:   0%|          | 0.00/2.53G [00:00<?, ?B/s]
# ✅ 成功就绪: ip-adapter-faceid-plusv2_sdxl.bin
# diffusion_models/ltx-2.3-22b-distilled-1(…):   0%|          | 0.00/25.2G [00:00<?, ?B/s]
# ✅ 成功就绪: ltx-2.3-22b-ic-lora-lipdub-0.9.safetensors
# vae/LTX23_video_vae_bf16.safetensors:   0%|          | 0.00/1.45G [00:00<?, ?B/s]
# ✅ 成功就绪: CLIP-ViT-H-14-laion2B-s32B-b79K.safetensors
# vae/LTX23_audio_vae_bf16.safetensors:   0%|          | 0.00/365M [00:00<?, ?B/s]
# ✅ 成功就绪: LTX23_video_vae_bf16.safetensors
# ltx2.3-ic-watermark-remove-general.safet(…):   0%|          | 0.00/327M [00:00<?, ?B/s]
# ✅ 成功就绪: ltx-2.3-22b-distilled-lora-384-1.1.safetensors
# ltx2.3-ic-subtitles-remove-general.safet(…):   0%|          | 0.00/327M [00:00<?, ?B/s]
# ✅ 成功就绪: LTX23_audio_vae_bf16.safetensors
# ltx2.3-video-restoration-general.safeten(…):   0%|          | 0.00/101M [00:00<?, ?B/s]
# ✅ 成功就绪: ltx2.3-ic-watermark-remove-general-lora.safetensors
# ltx2.3-ic-video-upscale-general.safetens(…):   0%|          | 0.00/327M [00:00<?, ?B/s]
# ✅ 成功就绪: ltx2.3-ic-subtitles-remove-general-lora.safetensors
# ltx2.3-resolution-enhancement-guofeng.sa(…):   0%|          | 0.00/428M [00:00<?, ?B/s]
# ✅ 成功就绪: ltx2.3-video-restoration-general-lora.safetensors
# vae/taeltx2_3.safetensors:   0%|          | 0.00/23.5M [00:00<?, ?B/s]
# ✅ 成功就绪: ltx2.3-ic-video-upscale-general-lora.safetensors
# ✅ 成功就绪: taeltx2_3.safetensors
# ✅ 成功就绪: ltx2.3-transition.safetensors
# ✅ 成功就绪: LTX-2.3-Guofeng-V0.1.safetensors
# ✅ 成功就绪: ltx-2.3-22b-distilled-1.1.safetensors
# ✅ 成功就绪: ltx-2.3-22b-distilled-1.1_transformer_only_fp8_scaled.safetensors
# ✅ 成功就绪: gemma_3_12B_it_fp4_mixed.safetensors
# ✅ 成功就绪: ltx-2.3-22b-dev-fp8.safetensors
#
# 🎉 全量模型并发同步 & 路径纠偏全部完成！

# %% [markdown]
# 16g显存运行模型

# %%
# ==========================================
# Cell 3: 终极模型多线程极速同步 (精准路径修正版)
# ==========================================
import os
import shutil
from google.colab import userdata
from huggingface_hub import hf_hub_download
from concurrent.futures import ThreadPoolExecutor

os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
try:
    os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')
except:
    raise Exception("❌ 请在左侧 '🔑 Secrets' 中添加 'HF_TOKEN'")

# 这一次，repo_id 和 filename 被精准映射到了各自真实的 HF 仓库
downloads = [
    # --- 1. 之前已成功的基础模型与 LoRA ---
   # {"repo_id": "Lightricks/LTX-2.3", "filename": "ltx-2.3-22b-distilled-lora-384-1.1.safetensors", "local_dir": "/content/ComfyUI/models/loras"},
    #{"repo_id": "Lightricks/LTX-2.3", "filename": "ltx-2.3-spatial-upscaler-x2-1.1.safetensors", "local_dir": "/content/ComfyUI/models/latent_upscale_models"},
   # {"repo_id": "Lightricks/LTX-2.3-22b-IC-LoRA-Union-Control", "filename": "ltx-2.3-22b-ic-lora-union-control-ref0.5.safetensors", "local_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2.3", "filename": "ltx-2.3-22b-distilled-1.1.safetensors", "local_dir": "/content/ComfyUI/models/checkpoints"},

    # --- 2. VAE 模型 (Kijai 大佬的拆分仓库) ---
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "vae/LTX23_audio_vae_bf16.safetensors", "local_dir": "/content/ComfyUI/models/vae"},
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "vae/LTX23_video_vae_bf16.safetensors", "local_dir": "/content/ComfyUI/models/vae"},
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "vae/taeltx2_3.safetensors", "local_dir": "/content/ComfyUI/models/vae"},

    # --- 3. Text Encoders / CLIP ---
    # Gemma 在 Comfy-Org 的 LTX-2 (注意不是 2.3) 仓库里
    #{"repo_id": "Comfy-Org/ltx-2", "filename": "split_files/text_encoders/gemma_3_12B_it_fp4_mixed.safetensors", "local_dir": "/content/ComfyUI/models/text_encoders"},
    # 投影层在 Kijai 的仓库里
    #{"repo_id": "Kijai/LTX2.3_comfy", "filename": "text_encoders/ltx-2.3_text_projection_bf16.safetensors", "local_dir": "/content/ComfyUI/models/text_encoders"},

    # --- 4. UNET / Diffusion Models ---
    # GGUF 低显存版实际上由 vantagewithai / unsloth 维护
    #{"repo_id": "vantagewithai/LTX-2.3-GGUF", "filename": "dev/ltx-2-3-22b-dev-Q4_K_M.gguf", "local_dir": "/content/ComfyUI/models/unet"},
    # FP8 缩放版放在 Kijai 仓库的 diffusion_models 目录下
    #{"repo_id": "Kijai/LTX2.3_comfy", "filename": "diffusion_models/ltx-2.3-22b-dev_transformer_only_fp8_scaled.safetensors", "local_dir": "/content/ComfyUI/models/unet"},

    # --- 5. 镜头控制及动态 LoRA 组 ---
    # 动态控制 LoRA 在 Kijai 仓库
    {"repo_id": "Kijai/LTX2.3_comfy", "filename": "loras/ltx-2.3-22b-distilled-lora-dynamic_fro09_avg_rank_105_bf16.safetensors", "local_dir": "/content/ComfyUI/models/loras"},

    # 运镜 LoRA 官方为每个方向都单独建立了一个独立仓库！
    {"repo_id": "Lightricks/LTX-2-19b-LoRA-Camera-Control-Dolly-Left", "filename": "ltx-2-19b-lora-camera-control-dolly-left.safetensors", "local_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2-19b-LoRA-Camera-Control-Dolly-Right", "filename": "ltx-2-19b-lora-camera-control-dolly-right.safetensors", "local_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2-19b-LoRA-Camera-Control-Dolly-In", "filename": "ltx-2-19b-lora-camera-control-dolly-in.safetensors", "local_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2-19b-LoRA-Camera-Control-Dolly-Out", "filename": "ltx-2-19b-lora-camera-control-dolly-out.safetensors", "local_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2-19b-LoRA-Camera-Control-Jib-Up", "filename": "ltx-2-19b-lora-camera-control-jib-up.safetensors", "local_dir": "/content/ComfyUI/models/loras"},
    {"repo_id": "Lightricks/LTX-2-19b-LoRA-Camera-Control-Jib-Down", "filename": "ltx-2-19b-lora-camera-control-jib-down.safetensors", "local_dir": "/content/ComfyUI/models/loras"}
]

def download_and_flatten_model(task):
    # 提取纯文件名用于显示和最终路径
    display_name = task["filename"].split("/")[-1]
    target_dir = task["local_dir"]
    final_path = os.path.join(target_dir, display_name)

    try:
        # 下载到 HF 本地缓存 (不保留复杂的子文件夹结构)
        cached_path = hf_hub_download(repo_id=task["repo_id"], filename=task["filename"], repo_type="model")

        # 确保目标文件夹存在
        os.makedirs(target_dir, exist_ok=True)

        # 使用硬链接(或复制)直接把文件放在 ComfyUI 需要的最外层目录，避免节点找不到子文件夹内的文件
        if not os.path.exists(final_path):
            try:
                os.link(cached_path, final_path) # 首选硬链接，省空间
            except OSError:
                shutil.copy2(cached_path, final_path) # 跨盘符则复制

        print(f"✅ 成功加载: {display_name}")
    except Exception as e:
        print(f"❌ 失败 {display_name}: {e}")

print(f"🚀 开始精准校对并下载 {len(downloads)} 个模型...")

# 保持 6 线程
with ThreadPoolExecutor(max_workers=6) as executor:
    executor.map(download_and_flatten_model, downloads)

print("\n🎉 模型并发同步全部完成！请在 ComfyUI 界面点击 Refresh 刷新模型列表。")

# %%
# ==========================================
# Cell 4: FRP 内网穿透配置 (流式解压极速部署)
# ==========================================
import os
from google.colab import userdata

try:
    VPS_IP = userdata.get('VPS_IP')
    FRP_TOKEN = userdata.get('FRP_TOKEN')
except:
    raise Exception("❌ 请检查 'VPS_IP' 和 'FRP_TOKEN' 密钥是否配置！")

# 极速流式下载解压
if not os.path.exists("/content/frp_0.56.0_linux_amd64"):
    # !wget -qO- https://github.com/fatedier/frp/releases/download/v0.56.0/frp_0.56.0_linux_amd64.tar.gz | tar -xz -C /content

frpc_conf = f"""
serverAddr = "{VPS_IP}"
serverPort = 7000
auth.token = "{FRP_TOKEN}"

[[proxies]]
name = "comfyui_web_colab"
type = "tcp"
localIP = "127.0.0.1"
localPort = 8188
remotePort = 8090
"""
with open("/content/frp_0.56.0_linux_amd64/frpc.toml", "w") as f:
    f.write(frpc_conf.strip())

print("✅ FRP 极速部署并配置完毕！")
# Out:
# ✅ FRP 极速部署并配置完毕！

# %%
# ==========================================
# Cell 4: 启动 FRP 和 ComfyUI (重启界面时运行),不注册，启动快！访问域名
# ==========================================
import subprocess
import threading
import os
import configparser

import time

os.environ["OPENCV_IO_ENABLE_OPENEXR"] = "1"
# --- 新增：防断开保活机制 ---
def keep_alive():
    while True:
        time.sleep(300)  # 每 5 分钟
        print("\n[Keep-Alive] 保持 Colab 连接活跃中...")

print("⏳ 正在启动防断开后台保活线程...")
threading.Thread(target=keep_alive, daemon=True).start()
# --------------------------

# 1. 在后台新线程启动 FRP
def start_frpc():
    subprocess.run(["/content/frp_0.56.0_linux_amd64/frpc", "-c", "/content/frp_0.56.0_linux_amd64/frpc.toml"])

print("⏳ 正在后台唤起 FRP 穿透服务...")
threading.Thread(target=start_frpc, daemon=True).start()

print("============================================================")
print("✅ FRP 穿透已就绪！")
# 这里已修改为你的指定域名（保留了 8080 端口，如果你的服务端用 Nginx 做了 80 端口反代，可以把 :8080 删掉）
print("👉 启动完成后，请通过浏览器访问: http://cjp.usdream.dpdns.org:8090")
print("============================================================\n")

# ---------------------------------------------------------
# 新增：彻底拦截 ComfyUI-Manager 启动时的联网 Fetch 行为
# ---------------------------------------------------------
print("⏳ 正在配置 Manager 网络模式以跳过 Fetch...")
# 兼容所有版本的配置文件路径 (特别是最新的 __manager 路径)
manager_config_paths = [
    "/content/ComfyUI/user/__manager/config.ini",               # 最新版 V3.39+ 配置路径
    "/content/ComfyUI/user/default/ComfyUI-Manager/config.ini", # 较新版配置路径
    "/content/ComfyUI/custom_nodes/ComfyUI-Manager/config.ini"  # 老旧版配置路径
]

for config_path in manager_config_paths:
    os.makedirs(os.path.dirname(config_path), exist_ok=True)
    config = configparser.ConfigParser()

    if os.path.exists(config_path):
        config.read(config_path)

    if 'default' not in config:
        config['default'] = {}

    # 将网络模式改为 private
    config['default']['network_mode'] = 'private'

    with open(config_path, 'w') as f:
        config.write(f)

print("✅ 已成功切断 Fetch ComfyRegistry Data 流程！\n")
# ---------------------------------------------------------

# 2. 启动 ComfyUI 主程序
print("⏳ 正在启动 ComfyUI 主进程...\n")
# %cd /content/ComfyUI
# !python main.py --dont-print-server
# Out:
# ⏳ 正在启动防断开后台保活线程...
# ⏳ 正在后台唤起 FRP 穿透服务...
# ============================================================
# ✅ FRP 穿透已就绪！
# 👉 启动完成后，请通过浏览器访问: http://cjp.usdream.dpdns.org:8090
# ============================================================
#
# ⏳ 正在配置 Manager 网络模式以跳过 Fetch...
# ✅ 已成功切断 Fetch ComfyRegistry Data 流程！
#
# ⏳ 正在启动 ComfyUI 主进程...
#
# /content/ComfyUI
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:277: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-06-03 13:01:36.948
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# [INFO]
# Prestartup times for custom nodes:
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
# [INFO]    2.7 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
# [INFO]
# [WARNING] WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# [INFO] Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'gemv_awq_w4a16', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'stochastic_rounding_fp8']}
# [INFO] Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# [INFO] Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'gemv_awq_w4a16', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'stochastic_rounding_fp8']}
# [INFO] Checkpoint files will always be loaded safely.
# [INFO] Total VRAM 97250 MB, total RAM 181130 MB
# [INFO] pytorch version: 2.11.0+cu128
# [INFO] Set vram state to: NORMAL_VRAM
# [INFO] Device: cuda:0 NVIDIA RTX PRO 6000 Blackwell Server Edition : cudaMallocAsync
# [INFO] Using async weight offloading with 2 streams
# [INFO] Enabled pinned memory 163017.0
# [INFO] Using pytorch attention
# aimdo: /project/src-posix/cuda-funchooks.c:52:DEBUG:aimdo_setup_hooks: hooks successfully installed
# aimdo: /project/src/control.c:240:INFO:comfy-aimdo inited for GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition (VRAM: 97250 MB)
# [INFO] DynamicVRAM support detected and enabled
# [INFO] Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# [INFO] ComfyUI version: 0.23.0
# [INFO] comfy-aimdo version: 0.4.8
# [INFO] comfy-kitchen version: 0.2.10
# [INFO] comfyui-frontend-package version: 1.44.19
# [INFO] comfyui-workflow-templates version: 0.9.92
# [INFO] comfyui-embedded-docs version: 0.5.2
# [INFO] comfy-kitchen version: 0.2.10
# [INFO] comfy-aimdo version: 0.4.8
# [INFO] [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# [INFO] Asset seeder disabled
# /usr/local/lib/python3.12/dist-packages/kornia/feature/lightglue.py:44: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# [INFO] ### Loading: ComfyUI-Inspire-Pack (V1.23)
# Workspace manager - Openning file hash dict
# 🦄🦄Loading: Workspace Manager (V2.1.0)
# [FishAudioS2] 'audiotools' not found — auto-installing from: descript-audiotools>=0.7.2 --no-deps
#   ImportError: No module named 'audiotools'
#   sys.path: ['/content/ComfyUI/custom_nodes/ComfyUI-FishAudioS2/fish_speech_src', '/content/ComfyUI/comfy', '/content/ComfyUI', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/content/ComfyUI/custom_nodes/ComfyUI-Manager/glob']
#   sys.modules entry: <not in sys.modules>
# [FishAudioS2] Running: /usr/bin/python3 -m pip install descript-audiotools>=0.7.2 --no-deps
# [FishAudioS2] Successfully installed: descript-audiotools>=0.7.2 --no-deps
# 2026-06-03 13:01:54.805871: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-03 13:01:56.048179: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO] Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [INFO] NumExpr defaulting to 16 threads.
# [FishAudioS2] 'dac' not found — auto-installing from: descript-audio-codec --no-deps
#   ImportError: No module named 'dac'
#   sys.path: ['/content/ComfyUI/custom_nodes/ComfyUI-FishAudioS2/fish_speech_src', '/content/ComfyUI/comfy', '/content/ComfyUI', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/content/ComfyUI/custom_nodes/ComfyUI-Manager/glob', '/usr/local/lib/python3.12/dist-packages/IPython/extensions']
#   sys.modules entry: <not in sys.modules>
# [FishAudioS2] Running: /usr/bin/python3 -m pip install descript-audio-codec --no-deps
# [FishAudioS2] Successfully installed: descript-audio-codec --no-deps
# [FishAudioS2] torch 2.11.0+cu128 is a CUDA build — no restore needed.
# [FishAudioS2] Models folder registered: /content/ComfyUI/models/fishaudioS2
# [FishAudioS2] Registered 4 nodes (v0.5.3): Fish S2 TTS, Fish S2 Voice Clone TTS, Fish S2 Multi-Speaker TTS, Fish S2 Multi-Speaker Split TTS
#
# [rgthree-comfy] Loaded 48 fantastic nodes. 🎉
#
# [rgthree-comfy] ComfyUI's new Node 2.0 rendering may be incompatible with some rgthree-comfy nodes and features, breaking some rendering as well as losing the ability to access a node's properties (a vital part of many nodes). It also appears to run MUCH more slowly spiking CPU usage and causing jankiness and unresponsiveness, especially with large workflows. Personally I am not planning to use the new Nodes 2.0 and, unfortunately, am not able to invest the time to investigate and overhaul rgthree-comfy where needed. If you have issues when Nodes 2.0 is enabled, I'd urge you to switch it off as well and join me in hoping ComfyUI is not planning to deprecate the existing, stable canvas rendering all together.
#
# /content/ComfyUI/custom_nodes/ComfyUI_essentials/conditioning.py:234: SyntaxWarning: invalid escape sequence '\.'
#   double_blocks\.0\.(img|txt)_(mod|attn|mlp)\.(lin|qkv|proj|0|2)\.(weight|bias)=1.1
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# [ComfyUI-Easy-Use] server: v1.3.7 Loaded
# [ComfyUI-Easy-Use] web root: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use/web_version/v2 Loaded
# WAS Node Suite: Created default conf file at `/content/ComfyUI/custom_nodes/was-node-suite-comfyui/was_suite_config.json`.
# WAS Node Suite: OpenCV Python FFMPEG support is enabled
# WAS Node Suite Warning: `ffmpeg_bin_path` is not set in `/content/ComfyUI/custom_nodes/was-node-suite-comfyui/was_suite_config.json` config file. Will attempt to use system ffmpeg binaries if available.
# WAS Node Suite: Finished. Loaded 220 nodes successfully.
#
# 	"The only way to do great work is to love what you do." - Steve Jobs
#
# [INFO] ### Loading: ComfyUI-Impact-Pack (V8.28.3)
# [INFO] [Impact Pack] Wildcard total size (0.00 MB) is within cache limit (50.00 MB). Using full cache mode.
# [INFO] [Impact Pack] Wildcards loading done.
# [WARNING] xFormers not available
# [WARNING] xFormers not available
# xFormers not available
# xFormers not available
# [/content/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using ckpts path: /content/ComfyUI/custom_nodes/comfyui_controlnet_aux/ckpts
# [/content/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using symlinks: False
# [/content/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using ort providers: ['CUDAExecutionProvider', 'DirectMLExecutionProvider', 'OpenVINOExecutionProvider', 'ROCMExecutionProvider', 'CPUExecutionProvider', 'CoreMLExecutionProvider']
# /content/ComfyUI/custom_nodes/comfyui_controlnet_aux/node_wrappers/dwpose.py:26: UserWarning: DWPose: Onnxruntime not found or doesn't come with acceleration providers, switch to OpenCV with CPU device. DWPose might run very slowly
#   warnings.warn("DWPose: Onnxruntime not found or doesn't come with acceleration providers, switch to OpenCV with CPU device. DWPose might run very slowly")
#
# ----------------------------------------------------------------------
# [ComfyUI-Manager] NOTICE: First update after ComfyUI upgrade detected
#   - Both legacy and new directories exist.
#   - Running ComfyUI dependency installation...
# ----------------------------------------------------------------------
#
# [ComfyUI-Manager] ComfyUI dependencies installation completed.
#
# ----------------------------------------------------------------------
# [ComfyUI-Manager] NOTICE: Legacy settings migrated
#   - Old location: /content/ComfyUI/user/default/ComfyUI-Manager
#   - Backed up to: /content/ComfyUI/user/__manager/.legacy-manager-backup
#   - Please verify and remove the backup when no longer needed.
# ----------------------------------------------------------------------
#
# [INFO] ### Loading: ComfyUI-Manager (V3.40)
# [INFO] [ComfyUI-Manager] network_mode: private
# [INFO] [ComfyUI-Manager] ComfyUI per-queue preview override detected (PR #11261). Manager's preview method feature is disabled. Use ComfyUI's --preview-method CLI option or 'Settings > Execution > Live preview method'.
# [INFO] ### ComfyUI Version: v0.23.0-10-gbd7da053 | Released on '2026-06-02'
# [INFO]
# Import times for custom nodes:
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/cg-use-everywhere
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-PromptRelay
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/masquerade-nodes-comfyui
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyMath
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/WhatDreamsCost-ComfyUI
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Custom-Scripts
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Video-Depth-Anything
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI_essentials
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/comfyui_controlnet_aux
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Inspire-Pack
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI_IPAdapter_plus
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-LTXVideo
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-KJNodes
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack
# [INFO]    0.2 seconds: /content/ComfyUI/custom_nodes/comfyui-workspace-manager
# [INFO]    0.3 seconds: /content/ComfyUI/custom_nodes/ComfyUI_LayerStyle
# [INFO]    0.3 seconds: /content/ComfyUI/custom_nodes/ComfyUI-MediaMixer
# [INFO]    0.7 seconds: /content/ComfyUI/custom_nodes/ComfyUI-VideoHelperSuite
# [INFO]    1.2 seconds: /content/ComfyUI/custom_nodes/was-node-suite-comfyui
# [INFO]    1.4 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
# [INFO]    3.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use
# [INFO]    9.2 seconds: /content/ComfyUI/custom_nodes/ComfyUI-FishAudioS2
# [INFO]
# [INFO] Context impl SQLiteImpl.
# [INFO] Will assume non-transactional DDL.
# [INFO] Context impl SQLiteImpl.
# [INFO] Will assume non-transactional DDL.
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [INFO] [ComfyUI-Manager] The private comfyregistry is not yet supported in `network_mode=private`.
# [INFO] [ComfyUI-Manager] All startup tasks have been completed.
# [INFO] Running upgrade  -> 0001_assets, Initial assets schema
# Revision ID: 0001_assets
# Revises: None
# Create Date: 2025-12-10 00:00:00
# [INFO] Running upgrade 0001_assets -> 0002_merge_to_asset_references, Merge AssetInfo and AssetCacheState into unified asset_references table.
# [INFO] Running upgrade 0002_merge_to_asset_references -> 0003_add_metadata_job_id, Add system_metadata and job_id columns to asset_references.
# Change preview_id FK from assets.id to asset_references.id.
# [INFO] Database upgraded from None to 0003_add_metadata_job_id
# [INFO] Using RAM pressure cache.
#
# [Keep-Alive] 保持 Colab 连接活跃中...
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/widgetInputs.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/clipspace.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/groupNode.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/button.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/buttonGroup.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
# [INFO] got prompt
# [WARNING] invalid prompt: {'type': 'missing_node_type', 'message': "Node '去水印' has no class_type. The workflow may be corrupted or a custom node is missing.", 'details': "Node ID '#5131'", 'extra_info': {'node_id': '5131', 'class_type': None, 'node_title': '去水印'}}
# [INFO] got prompt
# [WARNING] invalid prompt: {'type': 'missing_node_type', 'message': "Node '去水印' has no class_type. The workflow may be corrupted or a custom node is missing.", 'details': "Node ID '#5131'", 'extra_info': {'node_id': '5131', 'class_type': None, 'node_title': '去水印'}}
#
# [Keep-Alive] 保持 Colab 连接活跃中...
# [INFO] got prompt
# [WARNING] invalid prompt: {'type': 'missing_node_type', 'message': "Node '去水印' has no class_type. The workflow may be corrupted or a custom node is missing.", 'details': "Node ID '#5131'", 'extra_info': {'node_id': '5131', 'class_type': None, 'node_title': '去水印'}}
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1514988643_custom-node-list.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/746607195_github-stats.json [DONE]
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extras.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1742899825_extension-node-map.json [DONE]
#
# [Keep-Alive] 保持 Colab 连接活跃中...
# FETCH DATA from: /content/ComfyUI/custom_nodes/ComfyUI-Manager/custom-node-list.json [DONE]
# FETCH DATA from: /content/ComfyUI/user/__manager/cache/1514988643_custom-node-list.json [DONE]
# Download: git clone 'https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes'
# 100% 1738.0/1738.0 [00:00<00:00, 1964.45it/s]
# Installation was successful.
# [INFO]
# [ComfyUI-Manager] Queued works are completed.
# {'install': 1}
# [INFO]
# After restarting ComfyUI, please refresh the browser.
#
# Restarting... [Legacy Mode]
#
#
# Command: ['/usr/bin/python3', 'main.py', '--dont-print-server']
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:277: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-06-03 13:27:59.324
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# [INFO]
# Prestartup times for custom nodes:
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use
# [INFO]    2.4 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
# [INFO]
# [WARNING] WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# [INFO] Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# [INFO] Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'gemv_awq_w4a16', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'stochastic_rounding_fp8']}
# [INFO] Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'gemv_awq_w4a16', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'stochastic_rounding_fp8']}
# [INFO] Checkpoint files will always be loaded safely.
# [INFO] Total VRAM 97250 MB, total RAM 181130 MB
# [INFO] pytorch version: 2.11.0+cu128
# [INFO] Set vram state to: NORMAL_VRAM
# [INFO] Device: cuda:0 NVIDIA RTX PRO 6000 Blackwell Server Edition : cudaMallocAsync
# [INFO] Using async weight offloading with 2 streams
# [INFO] Enabled pinned memory 163017.0
# [INFO] Using pytorch attention
# aimdo: /project/src-posix/cuda-funchooks.c:52:DEBUG:aimdo_setup_hooks: hooks successfully installed
# aimdo: /project/src/control.c:240:INFO:comfy-aimdo inited for GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition (VRAM: 97250 MB)
# [INFO] DynamicVRAM support detected and enabled
# [INFO] Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# [INFO] ComfyUI version: 0.23.0
# [INFO] comfy-aimdo version: 0.4.8
# [INFO] comfy-kitchen version: 0.2.10
# [INFO] comfyui-frontend-package version: 1.44.19
# [INFO] comfyui-workflow-templates version: 0.9.92
# [INFO] comfyui-embedded-docs version: 0.5.2
# [INFO] comfy-kitchen version: 0.2.10
# [INFO] comfy-aimdo version: 0.4.8
# [INFO] [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# [INFO] Asset seeder disabled
# /usr/local/lib/python3.12/dist-packages/kornia/feature/lightglue.py:44: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# [INFO] ### Loading: ComfyUI-Inspire-Pack (V1.23)
# Workspace manager - Openning file hash dict
# 🦄🦄Loading: Workspace Manager (V2.1.0)
# [INFO] Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [INFO] NumExpr defaulting to 16 threads.
# [FishAudioS2] Models folder registered: /content/ComfyUI/models/fishaudioS2
# [FishAudioS2] Registered 4 nodes (v0.5.3): Fish S2 TTS, Fish S2 Voice Clone TTS, Fish S2 Multi-Speaker TTS, Fish S2 Multi-Speaker Split TTS
#
# [rgthree-comfy] Loaded 48 epic nodes. 🎉
#
# [rgthree-comfy] ComfyUI's new Node 2.0 rendering may be incompatible with some rgthree-comfy nodes and features, breaking some rendering as well as losing the ability to access a node's properties (a vital part of many nodes). It also appears to run MUCH more slowly spiking CPU usage and causing jankiness and unresponsiveness, especially with large workflows. Personally I am not planning to use the new Nodes 2.0 and, unfortunately, am not able to invest the time to investigate and overhaul rgthree-comfy where needed. If you have issues when Nodes 2.0 is enabled, I'd urge you to switch it off as well and join me in hoping ComfyUI is not planning to deprecate the existing, stable canvas rendering all together.
#
# /content/ComfyUI/custom_nodes/ComfyUI_Comfyroll_CustomNodes/nodes/nodes_list.py:383: SyntaxWarning: invalid escape sequence '\W'
#   "optional": {"folder_path": ("STRING", {"default": "C:\Windows\Fonts", "multiline": False}),
# /content/ComfyUI/custom_nodes/ComfyUI_Comfyroll_CustomNodes/nodes/nodes_list.py:393: SyntaxWarning: invalid escape sequence '\W'
#   def make_list(self, source_folder, start_index, max_rows, folder_path="C:\Windows\Fonts"):
# /content/ComfyUI/custom_nodes/ComfyUI_Comfyroll_CustomNodes/nodes/nodes_xygrid.py:256: SyntaxWarning: invalid escape sequence '\R'
#   resolved_font_path = os.path.join(os.path.dirname(os.path.dirname(os.path.realpath(__file__))), "fonts\Roboto-Regular.ttf")
# ------------------------------------------
# Comfyroll Studio v1.76 :  175 Nodes Loaded
# ------------------------------------------
# ** For changes, please see patch notes at https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes/blob/main/Patch_Notes.md
# ** For help, please see the wiki at https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes/wiki
# ------------------------------------------
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# [ComfyUI-Easy-Use] server: v1.3.7 Loaded
# [ComfyUI-Easy-Use] web root: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use/web_version/v2 Loaded
# WAS Node Suite: OpenCV Python FFMPEG support is enabled
# WAS Node Suite Warning: `ffmpeg_bin_path` is not set in `/content/ComfyUI/custom_nodes/was-node-suite-comfyui/was_suite_config.json` config file. Will attempt to use system ffmpeg binaries if available.
# WAS Node Suite: Finished. Loaded 220 nodes successfully.
#
# 	"The best way to predict the future is to create it." - Peter Drucker
#
# [INFO] ### Loading: ComfyUI-Impact-Pack (V8.28.3)
# [INFO] [Impact Pack] Wildcard total size (0.00 MB) is within cache limit (50.00 MB). Using full cache mode.
# [INFO] [Impact Pack] Wildcards loading done.
# [WARNING] xFormers not available
# [WARNING] xFormers not available
# xFormers not available
# xFormers not available
# [/content/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using ckpts path: /content/ComfyUI/custom_nodes/comfyui_controlnet_aux/ckpts
# [/content/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using symlinks: False
# [/content/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using ort providers: ['CUDAExecutionProvider', 'DirectMLExecutionProvider', 'OpenVINOExecutionProvider', 'ROCMExecutionProvider', 'CPUExecutionProvider', 'CoreMLExecutionProvider']
#
# ----------------------------------------------------------------------
# [ComfyUI-Manager] NOTICE: Legacy backup exists
#   - Your old Manager data was backed up to:
#       /content/ComfyUI/user/__manager/.legacy-manager-backup
#   - Please verify and remove it when no longer needed.
# ----------------------------------------------------------------------
#
# [INFO] ### Loading: ComfyUI-Manager (V3.40)
# [INFO] [ComfyUI-Manager] network_mode: private
# [INFO] [ComfyUI-Manager] ComfyUI per-queue preview override detected (PR #11261). Manager's preview method feature is disabled. Use ComfyUI's --preview-method CLI option or 'Settings > Execution > Live preview method'.
# [INFO] ### ComfyUI Version: v0.23.0-10-gbd7da053 | Released on '2026-06-02'
# [INFO]
# Import times for custom nodes:
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/masquerade-nodes-comfyui
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-PromptRelay
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/cg-use-everywhere
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Custom-Scripts
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyMath
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI_essentials
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/WhatDreamsCost-ComfyUI
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Video-Depth-Anything
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI_IPAdapter_plus
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui_controlnet_aux
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-KJNodes
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui-workspace-manager
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-LTXVideo
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Inspire-Pack
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI_LayerStyle
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-VideoHelperSuite
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI_Comfyroll_CustomNodes
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-MediaMixer
# [INFO]    1.1 seconds: /content/ComfyUI/custom_nodes/was-node-suite-comfyui
# [INFO]    1.6 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use
# [INFO]    3.3 seconds: /content/ComfyUI/custom_nodes/ComfyUI-FishAudioS2
# [INFO]
# [INFO] Context impl SQLiteImpl.
# [INFO] Will assume non-transactional DDL.
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [INFO] Using RAM pressure cache.
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [INFO] [ComfyUI-Manager] The private comfyregistry is not yet supported in `network_mode=private`.
# [INFO] [ComfyUI-Manager] All startup tasks have been completed.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/widgetInputs.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/clipspace.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/groupNode.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/button.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [WARNING] [DEPRECATION WARNING] Detected import of deprecated legacy API: /scripts/ui/components/buttonGroup.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# [INFO] got prompt
# # 😺dzNodes: LayerStyle -> ImageScaleByAspectRatio V2 Processed 121 image(s).
# [INFO] Found quantization metadata version 1
# [INFO] Detected mixed precision quantization
# [INFO] Using mixed precision operations
# [INFO] Native ops: float8_e5m2, mxfp8, float8_e4m3fn, nvfp4
# [INFO] model weight dtype torch.bfloat16, manual cast: torch.bfloat16
# [INFO] model_type FLUX
# [INFO] VAE load device: cuda:0, offload device: cpu, dtype: torch.bfloat16
# [WARNING] no CLIP/text encoder weights in checkpoint, the text encoder model will not be loaded.
# [INFO] VAE load device: cuda:0, offload device: cpu, dtype: torch.float32
# [INFO] Requested to load VideoVAE
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Found quantization metadata version 1
# [INFO] Using MixedPrecisionOps for text encoder
# [INFO] CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# [INFO] Requested to load LTXAVTEModel_
# [INFO] Model LTXAVTEModel_ prepared for dynamic VRAM loading. 11200MB Staged. 0 patches attached. Force pre-loaded 400 weights: 1749 KB.
# [INFO] Model LTXAVTEModel_ prepared for dynamic VRAM loading. 11200MB Staged. 0 patches attached. Force pre-loaded 400 weights: 1749 KB.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Using sage attention mode: auto
# [INFO] Requested to load LTXAV
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
#   0% 0/5 [00:00<?, ?it/s,   Model Initializing ...  ]
# [Keep-Alive] 保持 Colab 连接活跃中...
# 100% 5/5 [00:22<00:00,  4.41s/it]
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Prompt executed in 132.74 seconds
# [INFO] got prompt
# [INFO] Model LTXAVTEModel_ prepared for dynamic VRAM loading. 11200MB Staged. 0 patches attached. Force pre-loaded 400 weights: 1749 KB.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
# 100% 5/5 [00:22<00:00,  4.41s/it]
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Prompt executed in 28.16 seconds
# [INFO] got prompt
# # 😺dzNodes: LayerStyle -> ImageScaleByAspectRatio V2 Processed 192 image(s).
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
#  20% 1/5 [00:07<00:30,  7.51s/it,  Model Initialization complete!  ]
# [Keep-Alive] 保持 Colab 连接活跃中...
# 100% 5/5 [00:37<00:00,  7.52s/it]
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Prompt executed in 58.25 seconds
# [INFO] got prompt
# [INFO] Model LTXAVTEModel_ prepared for dynamic VRAM loading. 11200MB Staged. 0 patches attached. Force pre-loaded 400 weights: 1749 KB.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
# 100% 5/5 [00:37<00:00,  7.52s/it]
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Prompt executed in 45.85 seconds
#
# [Keep-Alive] 保持 Colab 连接活跃中...
# [INFO] got prompt
# [INFO] Model LTXAVTEModel_ prepared for dynamic VRAM loading. 11200MB Staged. 0 patches attached. Force pre-loaded 400 weights: 1749 KB.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
# 100% 5/5 [00:37<00:00,  7.52s/it]
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Prompt executed in 45.78 seconds
# [INFO] got prompt
# [INFO] Using sage attention mode: auto
# [INFO] Requested to load LTXAV
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
# 100% 5/5 [00:37<00:00,  7.52s/it]
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Prompt executed in 48.83 seconds
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
# [INFO] got prompt
# [INFO] VAE load device: cuda:0, offload device: cpu, dtype: torch.float32
# [INFO] Found quantization metadata version 1
# [INFO] Using MixedPrecisionOps for text encoder
# [INFO] CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# [INFO] VAE load device: cuda:0, offload device: cpu, dtype: torch.bfloat16
# [INFO] model weight dtype torch.bfloat16, manual cast: None
# [INFO] model_type FLUX
# [INFO] VAE load device: cuda:0, offload device: cpu, dtype: torch.bfloat16
# [WARNING] no CLIP/text encoder weights in checkpoint, the text encoder model will not be loaded.
# [INFO] [PromptRelay] Auto-generated LTXV latent: 1248x704, 289 pixel frames (37 latent frames)
# [INFO] [PromptRelay] Global: tokens [0:1] (1 tokens)
# [INFO] [PromptRelay] Segment 0: tokens [1:7] (6 tokens)
# [INFO] [PromptRelay] Segment 1: tokens [7:44] (37 tokens)
# [INFO] Requested to load LTXAVTEModel_
# [INFO] Model LTXAVTEModel_ prepared for dynamic VRAM loading. 11200MB Staged. 0 patches attached. Force pre-loaded 400 weights: 1749 KB.
# [INFO] [PromptRelay] Latent: 37 frames, 858 tokens/frame, segments: [3, 34]
# [INFO] [PromptRelay] Auto-generated empty audio latent.
# [INFO] Requested to load TAEHV
# [INFO] Model TAEHV prepared for dynamic VRAM loading. 22MB Staged. 0 patches attached. Force pre-loaded 4 weights: 64 KB.
# [ERROR] !!! Exception during processing !!! Sizes of tensors must match except in dimension 2. Expected size 11 but got size 6 for tensor number 1 in the list.
# [ERROR] Traceback (most recent call last):
#   File "/content/ComfyUI/execution.py", line 536, in execute
#     output_data, output_ui, has_subgraph, has_pending_tasks = await get_output_data(prompt_id, unique_id, obj, input_data_all, execution_block_cb=execution_block_cb, pre_execute_cb=pre_execute_cb, v3_data=v3_data)
#                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/execution.py", line 336, in get_output_data
#     return_values = await _async_map_node_over_list(prompt_id, unique_id, obj, input_data_all, obj.FUNCTION, allow_interrupt=True, execution_block_cb=execution_block_cb, pre_execute_cb=pre_execute_cb, v3_data=v3_data)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/execution.py", line 310, in _async_map_node_over_list
#     await process_inputs(input_dict, i)
#   File "/content/ComfyUI/execution.py", line 298, in process_inputs
#     result = f(**inputs)
#              ^^^^^^^^^^^
#   File "/content/ComfyUI/comfy_api/internal/__init__.py", line 149, in wrapped_func
#     return method(locked_class, **inputs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy_api/latest/_io.py", line 1880, in EXECUTE_NORMALIZED
#     to_return = cls.execute(*args, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/custom_nodes/WhatDreamsCost-ComfyUI/ltx_director_guide.py", line 86, in execute
#     positive, negative, latent_image, noise_mask = cls.append_keyframe(
#                                                    ^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy_extras/nodes_lt.py", line 404, in append_keyframe
#     latent_image = torch.cat([latent_image, guiding_latent], dim=2)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Sizes of tensors must match except in dimension 2. Expected size 11 but got size 6 for tensor number 1 in the list.
#
# [INFO] Prompt executed in 18.39 seconds
# [INFO] got prompt
# [INFO] [PromptRelay] Auto-generated LTXV latent: 1248x704, 289 pixel frames (37 latent frames)
# [INFO] [PromptRelay] Global: tokens [0:1] (1 tokens)
# [INFO] [PromptRelay] Segment 0: tokens [1:12] (11 tokens)
# [INFO] [PromptRelay] Segment 1: tokens [12:49] (37 tokens)
# [INFO] Model LTXAVTEModel_ prepared for dynamic VRAM loading. 11200MB Staged. 0 patches attached. Force pre-loaded 400 weights: 1749 KB.
# [INFO] [PromptRelay] Latent: 37 frames, 858 tokens/frame, segments: [6, 31]
# [INFO] [PromptRelay] Auto-generated empty audio latent.
# [INFO] VAE load device: cuda:0, offload device: cpu, dtype: torch.bfloat16
# [INFO] Requested to load VideoVAE
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Requested to load LTXAV
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
#   0% 0/8 [00:00<?, ?it/s,   Model Initializing ...  ][INFO] [PromptRelay] Built penalty matrix (scaled): Lq=8580, Lk=1024, nonzero=183663/8785920
# [INFO] [PromptRelay] Built penalty matrix (scaled): Lq=302, Lk=1024, nonzero=6476/309248
# 100% 8/8 [00:14<00:00,  1.78s/it]
#
# [Keep-Alive] 保持 Colab 连接活跃中...
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
#   0% 0/4 [00:00<?, ?it/s,   Model Initializing ...  ][INFO] [PromptRelay] Built penalty matrix (scaled): Lq=34320, Lk=1024, nonzero=734626/35143680
# 100% 4/4 [00:28<00:00,  7.16s/it]
# [INFO] Requested to load AudioVAE
# [INFO] loaded completely;  693.46 MB loaded, full load: True
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Prompt executed in 74.35 seconds
# [INFO] got prompt
# [INFO] [PromptRelay] Auto-generated LTXV latent: 1248x704, 289 pixel frames (37 latent frames)
# [INFO] [PromptRelay] Global: tokens [0:1] (1 tokens)
# [INFO] [PromptRelay] Segment 0: tokens [1:12] (11 tokens)
# [INFO] [PromptRelay] Segment 1: tokens [12:51] (39 tokens)
# [INFO] Model LTXAVTEModel_ prepared for dynamic VRAM loading. 11200MB Staged. 0 patches attached. Force pre-loaded 400 weights: 1749 KB.
# [INFO] [PromptRelay] Latent: 37 frames, 858 tokens/frame, segments: [6, 31]
# [INFO] [PromptRelay] Auto-generated empty audio latent.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Requested to load LTXAV
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
#   0% 0/8 [00:00<?, ?it/s,   Model Initializing ...  ][INFO] [PromptRelay] Built penalty matrix (scaled): Lq=8580, Lk=1024, nonzero=188765/8785920
# [INFO] [PromptRelay] Built penalty matrix (scaled): Lq=302, Lk=1024, nonzero=6656/309248
# 100% 8/8 [00:14<00:00,  1.80s/it]
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Model LTXAV prepared for dynamic VRAM loading. 23835MB Staged. 1660 patches attached. Force pre-loaded 2104 weights: 3308 KB.
#   0% 0/4 [00:00<?, ?it/s,   Model Initializing ...  ][INFO] [PromptRelay] Built penalty matrix (scaled): Lq=34320, Lk=1024, nonzero=755032/35143680
# 100% 4/4 [00:28<00:00,  7.14s/it]
# [INFO] Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# [INFO] Prompt executed in 53.25 seconds
#
# [Keep-Alive] 保持 Colab 连接活跃中...
