# %% [markdown]
# <a href="https://colab.research.google.com/github/zencolab/WhatDreamsCost-ComfyUI/blob/main/LTX%202.3%20All-In-One(%E5%8E%BB%E5%AD%97%E5%B9%95%E6%B0%B4%E5%8D%B0%E9%AB%98%E6%B8%85%E6%A8%AA%E7%AB%96%E8%BD%AC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# Cell 1: ComfyUI + All-In-One 工作流必需节点
# ==========================================
import os, sys, subprocess
from pathlib import Path

print("=== 🚀 安装 ComfyUI + LTX 2.3 All-In-One 必需节点 ===")

BASE_DIR = Path("/content")
COMFY_DIR = BASE_DIR / "ComfyUI"
CUSTOM_NODES_DIR = COMFY_DIR / "custom_nodes"

def run(cmd, cwd=None, check=False):
    print(" ".join(map(str, cmd)))
    r = subprocess.run(cmd, cwd=cwd, text=True, capture_output=True)
    if r.stdout.strip():
        print(r.stdout.strip())
    if r.returncode != 0:
        print(r.stderr.strip())
        if check:
            raise RuntimeError("命令失败: " + " ".join(map(str, cmd)))
    return r

os.chdir(BASE_DIR)

if not COMFY_DIR.exists():
    run(["git", "clone", "https://github.com/comfyanonymous/ComfyUI", str(COMFY_DIR)], check=True)
else:
    run(["git", "pull"], cwd=COMFY_DIR)

os.chdir(COMFY_DIR)

run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
run([sys.executable, "-m", "pip", "install", "-q", "huggingface_hub", "hf_transfer", "opencv-python-headless"], check=True)

CUSTOM_NODES_DIR.mkdir(parents=True, exist_ok=True)

def install_node(repo_url):
    name = repo_url.rstrip("/").split("/")[-1].replace(".git", "")
    path = CUSTOM_NODES_DIR / name

    if not path.exists():
        run(["git", "clone", repo_url, str(path)])
    else:
        run(["git", "pull"], cwd=path)

    req = path / "requirements.txt"
    if req.exists():
        run([sys.executable, "-m", "pip", "install", "-q", "-r", str(req)])

# ==========================================
# ✅ 该 All-In-One workflow 必需节点
# ==========================================
required_nodes = [
    "https://github.com/ltdrdata/ComfyUI-Manager.git",
    "https://github.com/city96/ComfyUI-GGUF.git",
    "https://github.com/Lightricks/ComfyUI-LTXVideo.git",
    "https://github.com/kijai/ComfyUI-KJNodes.git",
    "https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git",
    "https://github.com/chrisgoringe/cg-use-everywhere.git",
    "https://github.com/evanspearman/ComfyMath.git",
    "https://github.com/rgthree/rgthree-comfy.git",
    "https://github.com/yolain/ComfyUI-Easy-Use.git",
    "https://github.com/ltdrdata/ComfyUI-Impact-Pack.git",
    "https://github.com/pythongosssss/ComfyUI-Custom-Scripts.git",
    "https://github.com/WASasquatch/was-node-suite-comfyui.git",
    "https://github.com/jamesWalker55/comfyui-various.git",
]

for repo in required_nodes:
    install_node(repo)

# ==========================================
# ❌ 本 workflow 暂不需要，保留注释
# ==========================================
unused_nodes = [
    # "https://github.com/WhatDreamsCost/WhatDreamsCost-ComfyUI.git",
    # "https://github.com/Fannovel16/comfyui_controlnet_aux.git",
    # "https://github.com/cubiq/ComfyUI_essentials.git",
    # "https://github.com/yuvraj108c/ComfyUI-Video-Depth-Anything.git",
    # "https://github.com/cubiq/ComfyUI_IPAdapter_plus.git",
    # "https://github.com/Saganaki22/ComfyUI-FishAudioS2.git",
    # "https://github.com/GoogleCloudPlatform/comfyui-google-genmedia-custom-nodes.git",
]

# 关键依赖
run([sys.executable, "-m", "pip", "install", "-q", "gguf", "onnxruntime-gpu", "scikit-image", "kornia==0.7.2"])

# 可选加速，失败不影响运行
run([sys.executable, "-m", "pip", "install", "-q", "sageattention"])

print("\n✅ Cell 1 完成")
# Out:
# === 🚀 安装 ComfyUI + LTX 2.3 All-In-One 必需节点 ===
# git pull
# Already up to date.
# /usr/bin/python3 -m pip install -q -r requirements.txt
# /usr/bin/python3 -m pip install -q huggingface_hub hf_transfer opencv-python-headless
# git pull
# Already up to date.
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt
# git clone https://github.com/city96/ComfyUI-GGUF.git /content/ComfyUI/custom_nodes/ComfyUI-GGUF
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/ComfyUI-GGUF/requirements.txt
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 5.2 MB/s eta 0:00:00
# git pull
# Already up to date.
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/ComfyUI-LTXVideo/requirements.txt
# git pull
# Already up to date.
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/ComfyUI-KJNodes/requirements.txt
# git pull
# Already up to date.
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/ComfyUI-VideoHelperSuite/requirements.txt
# git clone https://github.com/chrisgoringe/cg-use-everywhere.git /content/ComfyUI/custom_nodes/cg-use-everywhere
# git clone https://github.com/evanspearman/ComfyMath.git /content/ComfyUI/custom_nodes/ComfyMath
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/ComfyMath/requirements.txt
# git pull
# Already up to date.
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/rgthree-comfy/requirements.txt
# git pull
# Already up to date.
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use/requirements.txt
# git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack.git /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack/requirements.txt
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 10.3 MB/s eta 0:00:00
# git clone https://github.com/pythongosssss/ComfyUI-Custom-Scripts.git /content/ComfyUI/custom_nodes/ComfyUI-Custom-Scripts
# git clone https://github.com/WASasquatch/was-node-suite-comfyui.git /content/ComfyUI/custom_nodes/was-node-suite-comfyui
# /usr/bin/python3 -m pip install -q -r /content/ComfyUI/custom_nodes/was-node-suite-comfyui/requirements.txt
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 11.4 MB/s eta 0:00:00
# git clone https://github.com/jamesWalker55/comfyui-various.git /content/ComfyUI/custom_nodes/comfyui-various
# /usr/bin/python3 -m pip install -q gguf onnxruntime-gpu scikit-image kornia==0.7.2
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 MB 13.5 MB/s eta 0:00:00
# /usr/bin/python3 -m pip install -q sageattention
#
# ✅ Cell 1 完成

# %%
# ==========================================
# Cell 2: 下载 All-In-One workflow 所需模型
# ==========================================
import os, shutil
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
from huggingface_hub import hf_hub_download

print("=== 🚀 下载 LTX 2.3 All-In-One 模型 ===")

COMFY_DIR = Path("/content/ComfyUI")
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

try:
    from google.colab import userdata
    token = userdata.get("HF_TOKEN")
    if token:
        os.environ["HF_TOKEN"] = token
        print("✅ 已读取 HF_TOKEN")
except Exception:
    pass

downloads = [
    # ======================================
    # 1. GGUF 主模型
    # Workflow 使用名：ltx-2-3-22b-dev-Q4_K_M.gguf
    # HF 原名：ltx-2.3-22b-dev-Q4_K_M.gguf
    # ======================================
    {
        "repo_id": "unsloth/LTX-2.3-GGUF",
        "filename": "ltx-2.3-22b-dev-Q4_K_M.gguf",
        "final_dir": COMFY_DIR / "models" / "unet",
        "rename_to": "ltx-2-3-22b-dev-Q4_K_M.gguf",
    },

    # ======================================
    # 2. Distilled LoRA
    # ======================================
    {
        "repo_id": "Kijai/LTX2.3_comfy",
        "filename": "loras/ltx-2.3-22b-distilled-lora-dynamic_fro09_avg_rank_105_bf16.safetensors",
        "final_dir": COMFY_DIR / "models" / "loras",
        "flatten": True,
    },

    # ======================================
    # 3. Text Encoder
    # ======================================
    {
        "repo_id": "Comfy-Org/ltx-2",
        "filename": "split_files/text_encoders/gemma_3_12B_it_fp8_scaled.safetensors",
        "final_dir": COMFY_DIR / "models" / "text_encoders",
        "flatten": True,
    },
    {
        "repo_id": "Kijai/LTX2.3_comfy",
        "filename": "text_encoders/ltx-2.3_text_projection_bf16.safetensors",
        "final_dir": COMFY_DIR / "models" / "text_encoders",
        "flatten": True,
    },

    # ======================================
    # 4. VAE
    # ======================================
    {
        "repo_id": "Kijai/LTX2.3_comfy",
        "filename": "vae/LTX23_video_vae_bf16.safetensors",
        "final_dir": COMFY_DIR / "models" / "vae",
        "flatten": True,
    },
    {
        "repo_id": "Kijai/LTX2.3_comfy",
        "filename": "vae/LTX23_audio_vae_bf16.safetensors",
        "final_dir": COMFY_DIR / "models" / "vae",
        "flatten": True,
    },
    {
        "repo_id": "Kijai/LTX2.3_comfy",
        "filename": "vae/taeltx2_3.safetensors",
        "final_dir": COMFY_DIR / "models" / "vae",
        "flatten": True,
    },

    # ======================================
    # 5. Latent Upscaler
    # ======================================
    {
        "repo_id": "Lightricks/LTX-2.3",
        "filename": "ltx-2.3-spatial-upscaler-x2-1.1.safetensors",
        "final_dir": COMFY_DIR / "models" / "latent_upscale_models",
    },

    # ======================================
    # 6. IC-LoRA / 视频修复 / 去字幕 / 去水印 / 超分
    # Workflow 内有部分节点 mode=4，即默认 bypass；
    # 但为了完整兼容该 All-In-One，仍下载。
    # ======================================
    {
        "repo_id": "joyfox/LTX2.3-ICEdit-Insight",
        "filename": "ltx2.3-ic-watermark-remove-general.safetensors",
        "final_dir": COMFY_DIR / "models" / "loras",
    },
    {
        "repo_id": "joyfox/LTX2.3-ICEdit-Insight",
        "filename": "ltx2.3-ic-subtitles-remove-general.safetensors",
        "final_dir": COMFY_DIR / "models" / "loras",
    },
    {
        "repo_id": "joyfox/LTX2.3-ICEdit-Insight",
        "filename": "ltx2.3-video-restoration-general.safetensors",
        "final_dir": COMFY_DIR / "models" / "loras",
    },
    {
        "repo_id": "joyfox/LTX2.3-ICEdit-Insight",
        "filename": "ltx2.3-ic-video-upscale-general.safetensors",
        "final_dir": COMFY_DIR / "models" / "loras",
    },
    {
        "repo_id": "oumoumad/LTX-2.3-22b-IC-LoRA-Outpaint",
        "filename": "ltx-2.3-22b-ic-lora-outpaint.safetensors",
        "final_dir": COMFY_DIR / "models" / "loras",
    },
    {
        "repo_id": "Lightricks/LTX-2-19b-IC-LoRA-Detailer",
        "filename": "ltx-2-19b-ic-lora-detailer.safetensors",
        "final_dir": COMFY_DIR / "models" / "loras",
    },
]

# ❌ 本 workflow 不需要
unused_models = [
    # "ltx-2.3-22b-dev-fp8.safetensors",
    # "ltx-2.3-22b-distilled-1.1.safetensors",
    # "gemma_3_12B_it_fp4_mixed.safetensors",
    # "ip-adapter-faceid-plusv2_sdxl.bin",
    # "CLIP-ViT-H-14-laion2B-s32B-b79K.safetensors",
    # "s2-pro-fp8",
    # "Google GenMedia / Veo / Imagen 相关模型",
]

def download_model(task):
    final_dir = Path(task["final_dir"])
    final_dir.mkdir(parents=True, exist_ok=True)

    target_name = task.get("rename_to", Path(task["filename"]).name)
    final_path = final_dir / target_name

    if final_path.exists() and final_path.stat().st_size > 0:
        return f"⏩ 已存在: {target_name}"

    try:
        downloaded = hf_hub_download(
            repo_id=task["repo_id"],
            filename=task["filename"],
            repo_type="model",
            local_dir=str(final_dir),
        )
        downloaded = Path(downloaded)

        if task.get("flatten") or task.get("rename_to"):
            if downloaded.resolve() != final_path.resolve():
                if final_path.exists():
                    final_path.unlink()
                shutil.move(str(downloaded), str(final_path))

        return f"✅ 完成: {target_name}"

    except Exception as e:
        return f"❌ 失败: {target_name} | {e}"

print(f"🚀 共 {len(downloads)} 个模型任务")

with ThreadPoolExecutor(max_workers=4) as executor:
    futures = [executor.submit(download_model, x) for x in downloads]
    for f in as_completed(futures):
        print(f.result())

# 兼容目录：部分节点扫描 diffusion_models
unet_dir = COMFY_DIR / "models" / "unet"
diff_dir = COMFY_DIR / "models" / "diffusion_models"
diff_dir.mkdir(parents=True, exist_ok=True)

for f in unet_dir.glob("*"):
    if f.suffix.lower() in [".gguf", ".safetensors"]:
        link = diff_dir / f.name
        if not link.exists():
            try:
                link.symlink_to(f)
                print(f"🔗 diffusion_models 软链接: {f.name}")
            except Exception:
                pass

print("\n🎉 Cell 2 完成")
# Out:
# === 🚀 下载 LTX 2.3 All-In-One 模型 ===
# ✅ 已读取 HF_TOKEN
# 🚀 共 14 个模型任务
# ⏩ 已存在: ltx-2.3-22b-distilled-lora-dynamic_fro09_avg_rank_105_bf16.safetensors
# ⏩ 已存在: LTX23_video_vae_bf16.safetensors
# ⏩ 已存在: LTX23_audio_vae_bf16.safetensors
# ⏩ 已存在: taeltx2_3.safetensors
# ⏩ 已存在: ltx-2.3-spatial-upscaler-x2-1.1.safetensors
# ltx-2.3-22b-dev-Q4_K_M.gguf:   0%|          | 0.00/14.3G [00:00<?, ?B/s]
# ✅ 完成: ltx-2.3_text_projection_bf16.safetensors
# ltx2.3-ic-watermark-remove-general.safet(…):   0%|          | 0.00/327M [00:00<?, ?B/s]
# ✅ 完成: gemma_3_12B_it_fp8_scaled.safetensors
# ltx2.3-ic-subtitles-remove-general.safet(…):   0%|          | 0.00/327M [00:00<?, ?B/s]
# ltx2.3-video-restoration-general.safeten(…):   0%|          | 0.00/101M [00:00<?, ?B/s]
# ✅ 完成: ltx2.3-video-restoration-general.safetensors
# ltx2.3-ic-video-upscale-general.safetens(…):   0%|          | 0.00/327M [00:00<?, ?B/s]
# ✅ 完成: ltx2.3-ic-subtitles-remove-general.safetensors
# ltx-2.3-22b-ic-lora-outpaint.safetensors:   0%|          | 0.00/1.31G [00:00<?, ?B/s]
# ✅ 完成: ltx2.3-ic-watermark-remove-general.safetensors
# ltx-2-19b-ic-lora-detailer.safetensors:   0%|          | 0.00/2.62G [00:00<?, ?B/s]
# ✅ 完成: ltx2.3-ic-video-upscale-general.safetensors
# ✅ 完成: ltx-2.3-22b-ic-lora-outpaint.safetensors
# ✅ 完成: ltx-2-19b-ic-lora-detailer.safetensors
# ✅ 完成: ltx-2-3-22b-dev-Q4_K_M.gguf
# 🔗 diffusion_models 软链接: ltx-2-3-22b-dev-Q4_K_M.gguf
#
# 🎉 Cell 2 完成

# %%
# ==========================================
# Cell 3: FRP 内网穿透，可选
# ==========================================
import os, subprocess
from pathlib import Path

print("=== 🌐 配置 FRP，可选 ===")

try:
    from google.colab import userdata
    VPS_IP = userdata.get("VPS_IP")
    FRP_TOKEN = userdata.get("FRP_TOKEN")
except Exception:
    VPS_IP = None
    FRP_TOKEN = None

if not VPS_IP or not FRP_TOKEN:
    print("⚠️ 未设置 VPS_IP / FRP_TOKEN，跳过 FRP")
else:
    FRP_DIR = Path("/content/frp_0.56.0_linux_amd64")

    if not FRP_DIR.exists():
        subprocess.run(
            "wget -qO- https://github.com/fatedier/frp/releases/download/v0.56.0/frp_0.56.0_linux_amd64.tar.gz | tar -xz -C /content",
            shell=True,
            check=True,
        )

    conf = f'''
serverAddr = "{VPS_IP}"
serverPort = 7000
auth.token = "{FRP_TOKEN}"

[[proxies]]
name = "comfyui_web_colab"
type = "tcp"
localIP = "127.0.0.1"
localPort = 8188
remotePort = 8090
'''
    (FRP_DIR / "frpc.toml").write_text(conf.strip(), encoding="utf-8")
    print("✅ FRP 配置完成")
# Out:
# === 🌐 配置 FRP，可选 ===
# ✅ FRP 配置完成

# %%
# ==========================================
# Cell 4: 启动 ComfyUI
# ==========================================
import os, subprocess, threading, time, configparser
from pathlib import Path

COMFY_DIR = Path("/content/ComfyUI")
FRP_DIR = Path("/content/frp_0.56.0_linux_amd64")

os.environ["OPENCV_IO_ENABLE_OPENEXR"] = "1"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

def keep_alive():
    while True:
        time.sleep(300)
        print("\n[Keep-Alive] Colab 保活中...")

threading.Thread(target=keep_alive, daemon=True).start()

# 启动 FRP
frpc = FRP_DIR / "frpc"
frpc_conf = FRP_DIR / "frpc.toml"

if frpc.exists() and frpc_conf.exists():
    def start_frpc():
        subprocess.run([str(frpc), "-c", str(frpc_conf)])

    threading.Thread(target=start_frpc, daemon=True).start()
    print("✅ FRP 已启动")
    print("👉 访问: http://cjp.usdream.dpdns.org:8090")
else:
    print("⚠️ 未启用 FRP")

# Manager private 模式，减少启动 Fetch 等待
manager_paths = [
    COMFY_DIR / "user" / "__manager" / "config.ini",
    COMFY_DIR / "user" / "default" / "ComfyUI-Manager" / "config.ini",
    COMFY_DIR / "custom_nodes" / "ComfyUI-Manager" / "config.ini",
]

for p in manager_paths:
    p.parent.mkdir(parents=True, exist_ok=True)
    cfg = configparser.ConfigParser()

    if p.exists():
        cfg.read(p)

    if "default" not in cfg:
        cfg["default"] = {}

    cfg["default"]["network_mode"] = "private"

    with open(p, "w") as f:
        cfg.write(f)

print("✅ Manager private 模式完成")

os.chdir(COMFY_DIR)
print("🚀 启动 ComfyUI...")

subprocess.run([
    "python",
    "main.py",
    "--dont-print-server",
])
# Out:
# ✅ FRP 已启动
# 👉 访问: http://cjp.usdream.dpdns.org:8090
# ✅ Manager private 模式完成
# 🚀 启动 ComfyUI...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] Colab 保活中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] Colab 保活中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] Colab 保活中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] Colab 保活中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
#
# [Keep-Alive] Colab 保活中...
#
# [Keep-Alive] 保持 Colab 连接活跃中...
